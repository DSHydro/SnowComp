# %%
# import elevation
# import os
# import regionmask
import geopandas as gpd
import rasterio
import rioxarray

import xarray as xr
import matplotlib.pyplot as plt
from shapely.geometry import mapping

# %% [markdown]
# # Data preparation
# eg. Checking site code on aso_basin table, we will be wokring on USCATB for Tuolumne basion

# %%
ds = xr.open_dataset('./ASO_50m_lidar_data/ASO_50M_SWE_USCATB_20130403.tif')

# %%
ds
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:      (band: 1, x: 1062, y: 1007)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 8kB 2.543e+05 2.543e+05 ... 3.073e+05 3.073e+05
#   * y            (y) float64 8kB 4.23e+06 4.23e+06 ... 4.179e+06 4.179e+06
#     spatial_ref  int64 8B ...
# Data variables:
#     band_data    (band, y, x) float32 4MB ...

# %%
path_ua = './ASO_50m_lidar_data/'
files_ua = path_ua + 'ASO_50M_SWE_USCATB*.tif'
ds_ua = xr.open_mfdataset(files_ua, engine="netcdf4")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/jovyan/NSIDC-Data-Access-Notebook/notebooks/ASO_50m_lidar_data/ASO_50M_SWE_USCATB_20130403.tif',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'a7d98c09-f05c-4781-b82c-749232621f08']
#
# ...
